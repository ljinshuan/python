# %%
import pandas as pd
import numpy as np
from scipy.spatial.distance import cosine

# %%
# 加载数据
ratings=pd.read_csv("./ml-latest-small/ratings_named.csv")

# %%
rating_matrix=ratings.pivot_table(index="userId",values="rating",columns="movieId")

# %%
rating_matrix
# Out:
# movieId  1       2       3       4       5       6       7       8       \
# userId
# 1           4.0     NaN     4.0     NaN     NaN     4.0     NaN     NaN
# 2           NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 3           NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 4           NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 5           4.0     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# ...         ...     ...     ...     ...     ...     ...     ...     ...
# 606         2.5     NaN     NaN     NaN     NaN     NaN     2.5     NaN
# 607         4.0     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 608         2.5     2.0     2.0     NaN     NaN     NaN     NaN     NaN
# 609         3.0     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 610         5.0     NaN     NaN     NaN     NaN     5.0     NaN     NaN
#
# movieId  9       10      ...  193565  193567  193571  193573  193579  193581  \
# ...

# %%
 bool_array = rating_matrix.loc[1].notnull() & rating_matrix.loc[2].notnull()

# %%
rating_matrix.loc[1,bool_array]
# Out:
# movieId
# 333     5.0
# 3578    5.0
# Name: 1, dtype: float64

# %%
item_corr_matrix=rating_matrix.corr()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-23-f5ae435e7b3e> in <module>
# ----> 1 item_corr_matrix=rating_matrix.fillna(0).corr()
#
# /opt/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in corr(self, method, min_periods)
#    7498
#    7499         if method == "pearson":
# -> 7500             correl = libalgos.nancorr(ensure_float64(mat), minp=min_periods)
#    7501         elif method == "spearman":
#    7502             correl = libalgos.nancorr_spearman(ensure_float64(mat), minp=min_periods)
#
# KeyboardInterrupt:

# %%
item_corr_matrix
# Out:
# movieId    1         2         3         4         5         6         7       \
# movieId
# 1        1.000000  0.330978  0.487109  1.000000  0.310971  0.106465  0.208402
# 2        0.330978  1.000000  0.419564       NaN  0.562791  0.163510  0.430261
# 3        0.487109  0.419564  1.000000       NaN  0.602266  0.345069  0.554088
# 4        1.000000       NaN       NaN  1.000000  0.654654       NaN  0.203653
# 5        0.310971  0.562791  0.602266  0.654654  1.000000  0.291302  0.609119
# ...           ...       ...       ...       ...       ...       ...       ...
# 193581        NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 193583        NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 193585        NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 193587        NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 193609        NaN       NaN       NaN       NaN       NaN       NaN       NaN
#
# ...

# %%
# 评估用户2对电影1的喜好
# 取与1最相似的100部电影 

item_corr_matrix[1].drop(1).nlargest(100)
# Out:
# movieId
# 6619     1.0
# 40851    1.0
# 4        1.0
# 61       1.0
# 132      1.0
#         ...
# 3436     1.0
# 3453     1.0
# 3537     1.0
# 3545     1.0
# 3571     1.0
# Name: 1, Length: 100, dtype: float64

# %%
# 用户2评过分的电影与1最相似的电影交集
bool_array=rating_matrix.loc[2].notnull().isin(item_corr_matrix[1].drop(1).nlargest(100))

# %%
data=rating_matrix.loc[2,bool_array].index.to_series()

# %%
item_corr_matrix.loc[data][1].sum()
# Out:
# 7.054393482146911

# %%
item_corr_matrix.loc[318][1]
# Out:
# 0.17498446246489624

# %%
data
# Out:
# movieId
# 318       0.174984
# 333       0.204456
# 1704     -0.044629
# 3578      0.038711
# 6874      0.213290
# 8798      0.500006
# 46970     0.110377
# 48516     0.326149
# 58559     0.255290
# 60756     0.117348
# 68157     0.109531
# 71535    -0.037796
# 74458     0.378654
# 77455     0.459429
# 79132     0.076195
# 80489     0.368631
# 80906     0.688247
# 86345     0.577350
# 89774     0.696311
# 91529     0.315593
# 91658    -0.207787
# 99114     0.323829
# 106782    0.578479
# 109487    0.446161
# 112552    0.659713
# 114060   -1.000000
# 115713    0.463976
# 122882    0.261898
# 131724         NaN
# Name: 1, dtype: float64
